X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20251122T235949Z&X-Amz-SignedHeaders=host&X-Amz-Expires=299&X-Amz-Credential=ASIAQ3PHCVTYTRSVMM6P%2F20251122%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=03cd75ffa8d10dec9115521b18c0ce21b725b7f232b89e4b9e63edffe9fd5694&hash=f898c31947e3336a34cc3685fec650ac8027e0a49b86c17d80d5789d9c5e2439&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S1877705813016007&tid=spdf-9cc7ebec-11c2-43b9-8a09-e74e5f7ca7be&sid=ba2f34147139614caa89b1b29f17bace0fc1gxrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=0714560254035351020c&rr=9a2c61fc99331fd8&cc=ar) y realizar tres experimentos:
#
#     - 1.1. Medicion sobre todo el frame
#     - 1.2. Medicion sobre una ROI ubicada en el centro del frame. Area de la ROI = 5 o 10% del area total del frame.
#
# Opcional:
#
# - Medicion sobre una matriz de enfoque compuesta por un arreglo de NxM elementos rectangulares equespaciados. N y M son valores arbitrarios. Probar con valores 3x3, 7x5, etc... (al menos 3)
#
# Para cada experimento se debe presentar:
#
# - Una curva o varias curvas que muestren la evolcion de la metrica frame a frame donde se vea claramente cuando el algoritmo detecto el punto de maximo enfoque.
#
# 2. Cambiar la metrica de enfoque eligiendo uno de los algoritmos explicados en el apendice de: *Analysis of focus measure operators in shape-form-focus*.
#
# El algoritmo de deteccion a implementar debe detectar y devolver los puntos de maximo enfoque de manera automatica.
#
# **Puntos Extra**: Aplicar unsharp masking para expandir la zona de enfoque y recalcular la métrica.

# %% [markdown]
# # Codigo auxiliar
#
# - Librerias importadas
# - EDA
# - Funciones Auxiliares para Ej 1
# - Funciones Auxiliares para Ej 2

# %% [markdown]
# ### Librerias importadas

# %%
import math
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# ### EDA

# %%
video_path = "assets/focus_video.mov"

# %%
def mostrar_imagenes_grid(lista, cols=4, figsize=None, suptitle=None):
    pares = []
    for item in lista:
        if isinstance(item, dict):
            if 'imagen' in item and 'titulo' in item:
                pares.append((item['imagen'], item['titulo']))
            else:
                for k, v in item.items():
                    if isinstance(k, str) and isinstance(v, np.ndarray):
                        pares.append((v, k))  # {'Titulo': imagen}
                    else:
                        # Fallback genérico
                        pares.append((v, str(k)))
        elif isinstance(item, (tuple, list)) and len(item) >= 2:
            pares.append((item[0], item[1]))
        else:
            pares.append((item, ''))

    n = len(pares)
    if n == 0:
        raise ValueError('Lista vacía')

    rows = math.ceil(n / cols)
    if figsize is None:
        figsize = (4 * cols, 3.5 * rows)

    fig, axes = plt.subplots(rows, cols, figsize=figsize)
    axes = np.array(axes).reshape(rows, cols)

    for i, (imagen, titulo) in enumerate(pares):
        ax = axes.flat[i]
        if imagen is None or getattr(imagen, 'size', 0) == 0:
            ax.set_title(f'{titulo} (vacía)')
            ax.axis('off')
            continue
        if getattr(imagen, 'ndim', 0) == 2:
            img, cmap = imagen, 'gray'
        else:
            img, cmap = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB), None
        ax.imshow(img, cmap=cmap)
        if titulo:
            ax.set_title(titulo)
        ax.axis('off')

    for j in range(n, rows * cols):
        axes.flat[j].axis('off')

    if suptitle:
        fig.suptitle(suptitle)
    plt.tight_layout()
    if suptitle:
        plt.subplots_adjust(top=0.92)
    return fig, axes

# %%
# Usa el backend FFMPEG explícitamente (útil en mac si hay códecs HEVC)
cap = cv2.VideoCapture(str(video_path), cv2.CAP_FFMPEG)
if not cap.isOpened():
    raise RuntimeError(f"No se pudo abrir el video: {video_path}")

fps = cap.get(cv2.CAP_PROP_FPS)
n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
print(f"FPS={fps}, Frames={n_frames}, Tamaño={w}x{h}")

while True:
    ok, frame = cap.read()
    if not ok:
        break

list_of_frames = []
step = max(1, n_frames // 7)  # ~8 muestras a lo largo del video

for i in range(0, n_frames, step):
    cap.set(cv2.CAP_PROP_POS_FRAMES, i)
    ret, frame = cap.read()
    if not ret or frame is None:
        continue
    list_of_frames.append((frame, f"Frame {i}"))

cap.release()

mostrar_imagenes_grid(list_of_frames)
# Out:
# FPS=29.97002997002997, Frames=171, Tamaño=640x360
# (<Figure size 1600x700 with 8 Axes>,
#  array([[<Axes: title={'center': 'Frame 0'}>,
#          <Axes: title={'center': 'Frame 24'}>,
#          <Axes: title={'center': 'Frame 48'}>,
#          <Axes: title={'center': 'Frame 72'}>],
#         [<Axes: title={'center': 'Frame 96'}>,
#          <Axes: title={'center': 'Frame 120'}>,
#          <Axes: title={'center': 'Frame 144'}>,
#          <Axes: title={'center': 'Frame 168'}>]], dtype=object))

# %% [markdown]
# ### Funciones Auxiliares

# %%
def graficar_blur_fm_frames(xs, fm_values, min_idx, max_idx, min_val, max_val):
    plt.figure(figsize=(10, 4))
    plt.plot(xs, fm_values, label="frequency_blur_fm")
    plt.scatter([min_idx], [min_val], color='red', label=f"min={min_val:.4f} (f{min_idx})")
    plt.scatter([max_idx], [max_val], color='green', label=f"max={max_val:.4f} (f{max_idx})")
    plt.xlabel("Frame")
    plt.ylabel("FM")
    plt.title("frequency_blur_fm por frame")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

# %%
def central_crop(frame, ROI_from_center):
    """
    Toma el <ROI_from_center> % central de cada dimensión (ancho y alto) por defecto.
    ROI_from_center: ROI_from_centerción por lado en (0, 1], p.ej., 0.1 => 10% del ancho y 10% del alto.
    """
    assert 0 < ROI_from_center <= 1.0
    h, w = frame.shape[:2]
    ch = max(1, int(round(h * ROI_from_center)))
    cw = max(1, int(round(w * ROI_from_center)))
    y1 = (h - ch) // 2
    x1 = (w - cw) // 2
    return frame[y1:y1 + ch, x1:x1 + cw]

# %%
def frequency_blur_fm(image: np.ndarray) -> float:
    if image.ndim == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    gray = np.asarray(gray, dtype=np.float32)
    if gray.ndim != 2 or gray.size == 0:
        return 0.0
    rows, cols = gray.shape
    if rows == 0 or cols == 0:
        return 0.0
    # Step 1: Compute F which is the Fourier Transform representation of image I 
    F = np.fft.fft2(gray)
    # Step 2: Find Fc which is obtained by shifting the origin of F to centre. 
    Fc = np.fft.fftshift(F)
    # Step 3: Calculate AF = abs (Fc) where AF is the absolute value of the centered Fourier transform of image I. 
    AF = np.abs(Fc)
    # Step 4: Calculate M = max (AF) where M is the maximum value of the frequency component in F
    M = float(AF.max()) if AF.size else 0.0
    if M <= 0.0:
        return 0.0
    # Step 5: Calculate TH = the total number of pixels in F whose pixel value > thres, where thres = M/1000
    thres = M / 1000.0
    TH = int(np.count_nonzero(AF > thres))
    # Step 6: Calculate Image Quality measure (FM) from equation FM = TH / (rows*cols)
    FM = TH / float(rows * cols)
    return float(FM)

# %%
def lap1_energy(image: np.ndarray) -> float:
    if image.ndim == 3:
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    else:
        gray = image
    gray = np.asarray(gray, dtype=np.float32)
    if gray.ndim != 2 or gray.size == 0:
        return 0.0
    lap = cv2.Laplacian(gray, cv2.CV_32F, ksize=3)
    energy = float(np.sum(lap * lap))
    return energy

# %%
def unsharp_mask(image: np.ndarray, k: float = 1.5, sigma: float = 1.0) -> np.ndarray:
    if image is None or getattr(image, 'size', 0) == 0:
        return image
    orig_dtype = image.dtype
    img = image.astype(np.float32)
    blurred = cv2.GaussianBlur(img, (0, 0), sigmaX=sigma, sigmaY=sigma)
    sharpened = (1.0 + k) * img - k * blurred
    if np.issubdtype(orig_dtype, np.integer):
        sharpened = np.clip(sharpened, 0, 255).astype(orig_dtype)
    else:
        sharpened = sharpened.astype(np.float32)
    return sharpened

# %%
def get_cap_blur_fm_information(cap, metrica_enfoque, sharp, ROI_from_center):
    n_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fm_values = []
    min_idx = None
    max_idx = None
    min_val = None
    max_val = None
    min_frame = None
    max_frame = None
    i = 0
    while True:
        ok, frame = cap.read()
        if not ok or frame is None:
            break
        roi = central_crop(frame, ROI_from_center)
        if sharp:
            roi = unsharp_mask(roi, k=3, sigma=2)
        v = metrica_enfoque(roi)
        fm_values.append(v)
        if min_val is None or v < min_val:
            min_val = v
            min_idx = i
            min_frame = roi.copy()
        if max_val is None or v > max_val:
            max_val = v
            max_idx = i
            max_frame = roi.copy()
        i += 1
    return fm_values, min_idx, max_idx, min_val, max_val, min_frame, max_frame

# %%
def graficar_fm_video(video_path, metrica_enfoque=frequency_blur_fm, sharp=False, ROI_from_center=1):
    cap = cv2.VideoCapture(str(video_path), cv2.CAP_FFMPEG)
    if not cap.isOpened():
        cap = cv2.VideoCapture(str(video_path))
        if not cap.isOpened():
            raise RuntimeError(f"No se pudo abrir el video: {video_path}")
    fm_values, min_idx, max_idx, min_val, max_val, min_frame, max_frame = get_cap_blur_fm_information(cap, metrica_enfoque, sharp, ROI_from_center)
    cap.release()
    if len(fm_values) == 0:
        raise RuntimeError("No se pudieron leer frames del video.")
    xs = list(range(len(fm_values)))
    graficar_blur_fm_frames(xs, fm_values, min_idx, max_idx, min_val, max_val)

    lista = [
        (max_frame, f"Máximo FM (frame {max_idx}, {max_val:.4f})"),
        (min_frame, f"Mínimo FM (frame {min_idx}, {min_val:.4f})"),
    ]
    mostrar_imagenes_grid(lista, cols=2, suptitle="Frames de máximo y mínimo FM")
    return {
        "fm_values": fm_values,
        "min_idx": min_idx,
        "min_val": float(min_val),
        "max_idx": max_idx,
        "max_val": float(max_val),
    }

# %% [markdown]
# ### Funciones Auxiliares Comparacion de Metricas

# %%
def comparacion_metricas(res_1, res_2, metrica_enfoque_1, metrica_enfoque_2):
    # Comparación de métricas: frequency_blur_fm vs LAP1, normalizadas
    res_1_vals = res_1.get('fm_values')
    res_2_vals = res_2.get('fm_values')

    if res_1_vals is not None and res_2_vals is not None:
        res_1_vals = np.array(res_1_vals, dtype=float)
        res_2_vals = np.array(res_2_vals, dtype=float)

        # Normalización min-max para graficar en la misma escala
        def norm01(x):
            xmin, xmax = np.min(x), np.max(x)
            return (x - xmin) / (xmax - xmin + 1e-12)

        res_1_n = norm01(res_1_vals)
        res_2_n = norm01(res_2_vals)

        xs = np.arange(len(res_1_n))
        plt.figure(figsize=(10,4))
        plt.plot(xs, res_1_n, label=f'{metrica_enfoque_1} (norm)')
        plt.plot(xs, res_2_n, label=f'{metrica_enfoque_2} (norm)')
        plt.xlabel('Frame')
        plt.ylabel('Valor normalizado [0,1]')
        plt.title('Comparación de métricas de enfoque (normalizadas)')
        plt.grid(True)
        plt.legend()
        plt.tight_layout()
    else:
        print('No se encontraron valores para comparar')

# %% [markdown]
# # Resolución 1
#
# Se debe implementar un algoritmo que dada una imagen, o region, calcule la metrica propuesta en el paper [*Image Sharpness Measure for Blurred Images in Frequency Domain*](https://pdf.sciencedirectassets.com/278653/1-s2.0-S1877705813X00177/1-s2.0-S1877705813016007/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjEGgaCXVzLWVhc3QtMSJGMEQCIFxq%2FvgAOYE99%2BawX2xfYWDwkViH2bHb3gkKg4n1ccA2AiA2BSPSp7fVzA8xRqkiNZvAfceGJWV%2FflJzciiPMdlbRSqzBQgwEAUaDDA1OTAwMzU0Njg2NSIMB8U%2F53Amak0bDQGLKpAFTZiWobbsw%2FDPGqiqj%2FW94wE%2FA%2FA4TXzA3CxA9V809M1tpfQvHsy2ErKsQoSmCYZpV%2FVBeda8ioyCvL6NRPjQIUHHaaSZJUBvUVWb0oEF4a0kMkl8SpnxdOOeIjt0k0kpMDQ35ne9hkJ64iu7xyILXQrnFkSnMi1W8Mny9uZn0wpFx9dT3m9uB0c%2FOlzH5wmsaOS29pxeLa%2FynzxT1FbGXUrBrXJId9MW60kIc54KVorq2QOZ%2B1x%2Bmkjc751OPXJ7ltd0rzXhJKJHgWySL3qTV1yr%2FvyTZaOy8XoueQgMHhC53OQiuqOXf%2BeiBEGK1Tj%2BBGg70m%2FffX
xrqa&type=client&tsoh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&rh=d3d3LnNjaWVuY2VkaXJlY3QuY29t&ua=0714560254035351020c&rr=9a2c61fc99331fd8&cc=ar) vemos que el video comienza con frames de bajo enfoque, durante los frames 75 y 118 podemos considerar que tiene el mejor enfoque del video, y luego vuelve a disminuir.
#
# Esta primera metrica muestra que el frame mas enfocado es el 109 con un valor medido de 0.0278. Mientras que el mas desenfocado es el 10, con una medida de 0.0066.
#
# En las imagenes esto puede apreciarse claramente.

# %% [markdown]
# ## 1.2. Medicion sobre una ROI
#
# La ROI debe estar ubicada en el centro del frame. Area de la ROI = 10% del area total del frame.

# %%
res_10 = graficar_fm_video(video_path, metrica_enfoque=frequency_blur_fm, sharp=False, ROI_from_center=0.1)

# %% [markdown]
# Tomando como ROI el 10% central de la imagen, podemos observar que el grafico con las metricas de la imagen se mantienen relativamente parecidos al ROI del 100%. Podemos decir que en el ROI central, la imagen se comporta (en términos de enfoque medido) parecido a la imagen completa.
#
# El frame con mayor enfoque es el 91, y el con menor enfoque es el 32.
#
# En las imagenes se puede apreciar que el frame con menor enfoque muestra objetos indistinguibles entre sí.

# %% [markdown]
# # Resolución 2
#
# Cambiar la metrica de enfoque eligiendo uno de los algoritmos explicados en el apendice de: *Analysis of focus measure operators in shapeform focus*.

# %%
res_lap = graficar_fm_video(video_path, metrica_enfoque=lap1_energy, sharp=False, ROI_from_center=1)

# %% [markdown]
# En nuestro caso elegimos el algoritmo de Energia del Laplaciano (LAP1) porque esta familia de metricas tuvo el mejor rendimiento general en condiciones normales en los analisis del paper.
#
# Vemos que el grafico de metricas vuelve a ser parecido al anterior, mostrando ambos algoritmos llegan a resultados similares.
#
# El frame con mayor enfoque segun esta metrica es el 111, mientras que el de menor enfoque es el 1.

# %%
comparacion_metricas(res_100, res_lap, metrica_enfoque_1='frequency_blur_fm', metrica_enfoque_2='lap1_energy')

# %% [markdown]
# Comparando ambas mediciones, notamos que la mayor distancia entre metricas se encuentra en el frame 75.
#
# Podriamos comparar ambos detenidamente para definir que tipo de metrica nos sirve mas a nuestro analisis. La metrica del Laplaciano es menos permisiva en cuanto a desenfoque que el FM.
#
# Ambas metricas encuentran el frame con mayor enfoque cerca del frame 118.

# %% [markdown]
# # Unsharp Masking
# Aplicar unsharp masking para expandir la zona de enfoque y recalcular la métrica.

# %%
res_us = graficar_fm_video(video_path, metrica_enfoque=frequency_blur_fm, sharp=True, ROI_from_center=1)
res_lap = graficar_fm_video(video_path, metrica_enfoque=lap1_energy, sharp=False, ROI_from_center=1)

# %%
comparacion_metricas(res_100, res_us, metrica_enfoque_1='frequency_blur_fm', metrica_enfoque_2='unsharped_frequency_blur_fm')

# %%
res_us_lap = graficar_fm_video(video_path, metrica_enfoque=lap1_energy, sharp=True, ROI_from_center=1)
res_lap = graficar_fm_video(video_path, metrica_enfoque=lap1_energy, sharp=False, ROI_from_center=1)

# %%
comparacion_metricas(res_lap, res_us_lap, metrica_enfoque_1='lap1_energy', metrica_enfoque_2='unsharped_lap1_energy')
